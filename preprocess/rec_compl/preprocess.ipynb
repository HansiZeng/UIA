# %%
import os

from google.cloud import bigquery
import pandas as pd 
import numpy as np

client = bigquery.Client()
print("Client creating using default project: {}".format(client.project))

query = """
    SELECT * 
    FROM `gcp-ushi-digital-ds-qa.new_hansi_dataset.comp_rec_ClicksData_2core`;
    """
query_job = client.query(query)
compl_rec_df = query_job.to_dataframe()

query = """
    SELECT * 
    FROM `gcp-ushi-digital-ds-qa.new_hansi_dataset.hansi_rec_ClicksData_5core`;
    """
query_job = client.query(query)
sim_rec_df = query_job.to_dataframe()

query = """
    SELECT *
    FROM `gcp-ushi-digital-ds-qa.new_hansi_dataset.search_ClicksData_1year_5core`;
"""
query_job = client.query(query)
search_df = query_job.to_dataframe()

query = """
    SELECT * 
    FROM `gcp-ushi-digital-ds-qa.hansi_dataset.all_products_info`;
    """
query_job = client.query(query)
product_df = query_job.to_dataframe()
print("product_df = {:,}".format(len(product_df)))

all_products = set(product_df.product_id)
anchors = set(compl_rec_df.anchor)
compl_ivms = set(compl_rec_df.ivm)
all_compl_ivms = anchors.union(compl_ivms)

print("================================ For anchor_to_compl_ivms: ===================================")
print("number of unique product = {}, anchors = {:,}, complementary_compl_ivms = {:,}".format(len(all_products), len(anchors), len(compl_ivms)))
assert len(all_products & anchors) == len(anchors) and len(all_products & compl_ivms) == len(compl_ivms),(
    len(all_products & anchors), len(anchors), len(all_products & compl_ivms), len(compl_ivms)
)

all_sim_ivms = set(sim_rec_df.anchor).union(set(sim_rec_df.ivm))
print("================================ After updating anchor_to_similar_ivms: ===================================")
print("all_compl_ivms = {:,}, all_sim_ivms = {:,}".format(len(all_compl_ivms), len(all_sim_ivms)))
print("sim_compl_intersect = {:,} ({:.3f})".format(len(all_compl_ivms & all_sim_ivms), len(all_compl_ivms & all_sim_ivms) / len(all_compl_ivms)))
print("all_ivms = {:,}".format(len(all_compl_ivms | all_sim_ivms)))
all_ivms = all_compl_ivms | all_sim_ivms

assert len(all_products & all_ivms) == len(all_ivms), (len(all_products & all_ivms), len(all_ivms))
# Out:
# Client creating using default project: gcp-ushi-digital-ds-qa
# product_df = 2,260,878
# ================================ For anchor_to_compl_ivms: ===================================
# number of unique product = 2260878, anchors = 86,870, complementary_compl_ivms = 65,561
# ================================ After updating anchor_to_similar_ivms: ===================================
# all_compl_ivms = 109,758, all_sim_ivms = 256,765
# sim_compl_intersect = 87,425 (0.797)
# all_ivms = 279,098

# %%
# statistics
ivm_to_queries = search_df.groupby("ivm")["query"].apply(list)
query_lengths = np.array([len(x) for x in ivm_to_queries.values])
all_queries = set(search_df["query"])
print("all queries = {}".format(len(all_queries)))
print("total ivms (queries) = {:,}, length >=3 = {:,}, length >= 5 = {:,}".format(
    len(query_lengths), np.sum(query_lengths >=3), np.sum(query_lengths >= 5) ))

anchor_to_compl_ivms = compl_rec_df.groupby("anchor")["ivm"].apply(list)
compl_ivms_length = np.array([len(x) for x in anchor_to_compl_ivms.values])
print("================================ For anchor_to_compl_ivms: ===================================")
print("total_compl_ivms = {:,}, length >=3 = {:,}, length >= 5 = {:,}".format(len(compl_ivms_length), np.sum(compl_ivms_length >=3), np.sum(compl_ivms_length >= 5) ))

anchor_to_sim_ivms = sim_rec_df.groupby("anchor")["ivm"].apply(list)
# Out:
# all queries = 953773
# total ivms (queries) = 360,744, length >=3 = 196,481, length >= 5 = 142,527
# ================================ For anchor_to_compl_ivms: ===================================
# total_compl_ivms = 86,870, length >=3 = 35,837, length >= 5 = 22,121

# %%
# map product --> text

from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
print("sep token = {}".format(tokenizer.sep_token))
from tqdm import tqdm 

ivm_to_title = {}
ivm_to_bullet = {}
ivm_to_catalog = {}
no_bulletin_ivms = set()
no_title_ivms = set()
no_catalog_ivms = set()

def preprocess_text(in_text):
    in_text = in_text.replace("\t", " ")
    in_text = in_text.replace("\n", " ")
    return in_text

for idx, row in tqdm(product_df.iterrows(), total=len(product_df)):
    product_id = row.product_id
    title = row.product_name if row.product_name != None else "No title"
    bullets = row.bullets if row.bullets != None else "No bullets"
    catalog = row.catalog_name if row.catalog_name != None else "No catalog"
    
    if row.product_name == None:
        no_title_ivms.add(product_id)
    if row.bullets == None:
        no_bulletin_ivms.add(product_id)
    if row.catalog_name == None:
        no_catalog_ivms.add(product_id)
    
    title = preprocess_text(title)
    bullets = preprocess_text(bullets)
    catalog = preprocess_text(catalog)
    
    ivm_to_title[product_id] = title
    ivm_to_bullet[product_id] = bullets
    ivm_to_catalog[product_id] = catalog

# sanity check
print("ivm_to_title = {:,}, ivm_to_bullet = {:,}, ivm_to_catalog = {:,}, products no bulletin = {:,}, no title = {:,}, no catalog = {:,}".format(
    len(ivm_to_title), len(ivm_to_bullet), len(ivm_to_catalog), len(no_bulletin_ivms), len(no_title_ivms), len(no_catalog_ivms)
))

assert len(ivm_to_title) == len(ivm_to_bullet) == len(ivm_to_catalog) == len(product_df)
# Out:
# sep token = [SEP]
# 100%|██████████| 2260878/2260878 [03:45<00:00, 10027.42it/s]
# ivm_to_title = 2,260,878, ivm_to_bullet = 2,260,878, ivm_to_catalog = 2,260,878, products no bulletin = 0, no title = 21, no catalog = 4,519

# %%
# anchor_to_compl_ivms
# [{anchor_A: {sim_ivms: {}, queries: {}}, compl_ivms: {sim_ivm: {}, query: {}}}, ..., {...}]
import ujson

from tqdm import tqdm

# map to pid and qid
ivm_to_pid = {ivm: pid for pid, ivm in enumerate(list(all_products))}
pid_to_ivm = {pid: ivm for ivm, pid in ivm_to_pid.items()}
query_to_qid = {query: qid for qid, query in enumerate(list(all_queries))}
qid_to_query = {qid: query for query, qid in query_to_qid.items()}

pid_to_title = {ivm_to_pid[ivm]: title for ivm, title in ivm_to_title.items()}
pid_to_bullet = {ivm_to_pid[ivm]: bullet for ivm, bullet in ivm_to_bullet.items()}
pid_to_catalog = {ivm_to_pid[ivm]: catalog for ivm, catalog in ivm_to_catalog.items()}

# start to one-hop examples construction
#anchor_to_sim_ivms = anchor_to_sim_ivms.to_dict()
#anchor_to_compl_ivms = anchor_to_compl_ivms.to_dict()
#ivm_to_queries = ivm_to_queries.to_dict()

aid_to_sim_pids = {ivm_to_pid[anchor]: [ivm_to_pid[ivm] for ivm in sim_ivms] for anchor, sim_ivms in anchor_to_sim_ivms.items()}
aid_to_compl_pids = {ivm_to_pid[anchor]: [ivm_to_pid[ivm] for ivm in compl_ivms] for anchor, compl_ivms in anchor_to_compl_ivms.items()}
pid_to_qids = {ivm_to_pid[anchor]: [query_to_qid[query] for query in _queries] for anchor, _queries in ivm_to_queries.items()}

one_hop_examples = []
for aid, compl_pids in tqdm(aid_to_compl_pids.items(), ):
    example = {aid: {}, "compl_pids": {}}
    if aid in aid_to_sim_pids:
        example[aid]["sim_pids"] = aid_to_sim_pids[aid]
    else:
        example[aid]["sim_pids"] = []
    
    if aid in pid_to_qids:
        example[aid]["qids"] = pid_to_qids[aid]
    else:
        example[aid]["qids"] = []
    
    for compl_pid in compl_pids:
        example["compl_pids"][compl_pid] = {}
        if compl_pid in aid_to_sim_pids:
            example["compl_pids"][compl_pid]["sim_pids"] = aid_to_sim_pids[compl_pid]
        else:
            example["compl_pids"][compl_pid]["sim_pids"] = []

        if compl_pid in pid_to_qids:
            example["compl_pids"][compl_pid]["qids"] = pid_to_qids[compl_pid]
        else:
            example["compl_pids"][compl_pid]["qids"] = []
        
        if compl_pid in aid_to_compl_pids:
            example["compl_pids"][compl_pid]["compl_pids"] = aid_to_compl_pids[compl_pid]
        else:
            example["compl_pids"][compl_pid]["compl_pids"] = []
    
    one_hop_examples.append(example)
    
# statistics
cur_obj = None
# sim_ivms length 
ohop_sim_ivms_lengths = [len(exp[anc]["sim_pids"]) for exp in one_hop_examples for anc in exp.keys() if anc != "compl_pids"] 
cur_obj = ohop_sim_ivms_lengths
print("sim_ivms length: ")
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)
# number of query per anchor
print("number of query per anchor: ")
ohop_anc_queries_lengths = [len(exp[anc]["qids"]) for exp in one_hop_examples for anc in exp.keys() if anc != "compl_pids"] 
cur_obj = ohop_anc_queries_lengths
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)
# number of compl_ivms 
print("number of compl_pids: ")
ohop_anc_queries_lengths = []
for exp in one_hop_examples:
    ohop_anc_queries_lengths.append(len(exp["compl_pids"]))
cur_obj = ohop_anc_queries_lengths
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)
# number of queries per compl_ivm
print("number of queries per compl_pid: ")
ohop_num_queries_per_compl_pids = []
for exp in one_hop_examples:
    for compl_pid in exp["compl_pids"]:
        ohop_num_queries_per_compl_pids.append(len(exp["compl_pids"][compl_pid]["qids"]))
cur_obj = ohop_num_queries_per_compl_pids
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)
# number of queries (compl_ivm's) per anchor 
print("number of queries (compl_pid's) per anchor : ")
ohop_num_compl_queries_per_anchor = []
for exp in one_hop_examples:
    tmp = []
    for compl_pid in exp["compl_pids"]:
        tmp.append(len(exp["compl_pids"][compl_pid]["qids"]))
    ohop_num_compl_queries_per_anchor.append(sum(tmp))
cur_obj = ohop_num_compl_queries_per_anchor
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)

print("="*100)
# number of compl_pids per compl_ivm
print("number of compl_pids per compl_pid: ")
ohop_num_queries_per_compl_pids = []
for exp in one_hop_examples:
    for compl_pid in exp["compl_pids"]:
        ohop_num_queries_per_compl_pids.append(len(exp["compl_pids"][compl_pid]["compl_pids"]))
cur_obj = ohop_num_queries_per_compl_pids
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)
# number of compl_pids (compl_ivm's) per anchor 
print("number of compl_pids (compl_pid's) per anchor : ")
ohop_num_compl_queries_per_anchor = []
for exp in one_hop_examples:
    tmp = []
    for compl_pid in exp["compl_pids"]:
        tmp.append(len(exp["compl_pids"][compl_pid]["compl_pids"]))
    ohop_num_compl_queries_per_anchor.append(sum(tmp))
cur_obj = ohop_num_compl_queries_per_anchor
print("min = {}, max = {}, 25% = {:.1f}, 50% = {:.1f}, 75% = {:.1f}".format(min(cur_obj), max(cur_obj), np.quantile(cur_obj, 0.25),
                                                                           np.quantile(cur_obj, 0.55), np.quantile(cur_obj, 0.75)
                                                                           ))
print("="*100)
# Out:
# 100%|██████████| 86870/86870 [00:01<00:00, 54987.47it/s]
# sim_ivms length:
# min = 0, max = 47, 25% = 1.0, 50% = 5.0, 75% = 9.0
# ====================================================================================================
# number of query per anchor:
# min = 0, max = 1415, 25% = 4.0, 50% = 16.0, 75% = 36.0
# ====================================================================================================
# number of compl_pids:
# min = 1, max = 74, 25% = 1.0, 50% = 2.0, 75% = 5.0
# ====================================================================================================
# number of queries per compl_pid:
# min = 0, max = 1415, 25% = 15.0, 50% = 51.0, 75% = 99.0
# ====================================================================================================
# number of queries (compl_pid's) per anchor :
# min = 0, max = 11420, 25% = 14.0, 50% = 100.0, 75% = 306.0
# ====================================================================================================
# ====================================================================================================
# number of compl_pids per compl_pid:
# min = 0, max = 74, 25% = 3.0, 50% = 11.0, 75% = 17.0
# ====================================================================================================
# number of compl_pids (compl_pid's) per anchor :
# min = 0, max = 817, 25% = 2.0, 50% = 16.0, 75% = 43.0
# ====================================================================================================

# %%
# split train, val, test 
import numpy as np 
np.random.seed(4680)

val_test_indices = np.random.choice(np.arange(0, len(one_hop_examples)), int(0.2*len(one_hop_examples)), replace=False)
val_indices = val_test_indices[:int(0.5*len(val_test_indices))]
test_indices = val_test_indices[int(0.5*len(val_test_indices)):]

train_ohop_examples = []
val_ohop_examples = []
test_ohop_examples = []

for idx, example in enumerate(one_hop_examples):
    if idx in val_indices:
        val_ohop_examples.append(example)
    elif idx in test_indices:
        test_ohop_examples.append(example)
    else:
        train_ohop_examples.append(example)
print("train example = {:,}, val example = {:,}, test example = {:,}".format(len(train_ohop_examples), len(val_ohop_examples), len(test_ohop_examples)))
assert len(train_ohop_examples) + len(val_ohop_examples) + len(test_ohop_examples) == len(one_hop_examples)
# Out:
# train example = 69,496, val example = 8,687, test example = 8,687

# %%
# write to disk
import os 
import copy

def example_qids_to_queries(example):
    _exp = copy.deepcopy(example)
    new_exp = {}
    for key_1, vals_1 in _exp.items():
        if key_1 != "compl_pids":
            new_exp[key_1] = {}
            for key_2, vals_2 in _exp[key_1].items():
                if key_2 == "qids":
                    vals_2 = [qid_to_query[qid] for qid in vals_2]
                new_exp[key_1][key_2] = vals_2
        else:
            new_exp[key_1] = {}
            for key_2, vals_2 in _exp[key_1].items():
                new_exp[key_1][key_2] = {}
                for key_3, val_3 in vals_2.items():
                    if key_3 == "qids":
                        val_3 = [qid_to_query[qid] for qid in val_3]
                    new_exp[key_1][key_2][key_3] = val_3
    return new_exp

out_dir = "/home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
    
with open(os.path.join(out_dir, "collection_title.tsv"), "w") as fout:
    for pid, title in pid_to_title.items():
        fout.write(f"{pid}\t{title}\n")
        
with open(os.path.join(out_dir, "collection_bullet.tsv"), "w") as fout:
    for pid, bullet in pid_to_bullet.items():
        fout.write(f"{pid}\t{bullet}\n")
        
with open(os.path.join(out_dir, "collection_catalog.tsv"), "w") as fout:
    for pid, catalog in pid_to_catalog.items():
        fout.write(f"{pid}\t{catalog}\n")
        
with open(os.path.join(out_dir, "product.jsonl"), "w") as fout:
    for aid in pid_to_title:
        text = pid_to_title[aid] + " " + tokenizer.sep_token + " " + pid_to_catalog[aid] + " " + tokenizer.sep_token + " " + pid_to_bullet[aid]
        example = {"id": aid, "contents": text}
        fout.write(ujson.dumps(example) + "\n")
        
with open(os.path.join(out_dir, "one_hop_examples.jsonl"), "w") as fout:
    for example in one_hop_examples:
        fout.write(ujson.dumps(example) + "\n")

with open(os.path.join(out_dir, "one_hop_examples_queries.jsonl"), "w") as fout:
    for example in one_hop_examples:
        fout.write(ujson.dumps(example_qids_to_queries(example)) + "\n")
        
with open(os.path.join(out_dir, "queries.tsv"), "w") as fout:
    for query, qid in query_to_qid.items():
        fout.write(f"{qid}\t{query}\n")
        
with open(os.path.join(out_dir, "anchors_title.train.tsv"), "w") as fout:
    with open(os.path.join(out_dir, "anchors_title_catalog.train.tsv"), "w") as fout2:
        with open(os.path.join(out_dir, "anchors_tcb.train.tsv"), "w") as fout3:
            for example in train_ohop_examples:
                for key in example:
                    if key == "compl_pids":
                        continue
                    aid = key
                    _title = pid_to_title[aid]
                    _tc = _title + " " + tokenizer.sep_token + " " + pid_to_catalog[aid]
                    _tcb = _tc + " " + tokenizer.sep_token + " " + pid_to_bullet[aid]
                    fout.write(f"{aid}\t{_title}\n")
                    fout2.write(f"{aid}\t{_tc}\n")
                    fout3.write(f"{aid}\t{_tcb}\n")
        
with open(os.path.join(out_dir, "anchors_title.val.tsv"), "w") as fout:
    with open(os.path.join(out_dir, "anchors_title_catalog.val.tsv"), "w") as fout2:
        with open(os.path.join(out_dir, "anchors_tcb.val.tsv"), "w") as fout3:
            for example in val_ohop_examples:
                for key in example:
                    if key == "compl_pids":
                        continue
                    aid = key
                    _title = pid_to_title[aid]
                    _tc = _title + " " + tokenizer.sep_token + " " + pid_to_catalog[aid]
                    _tcb = _tc + " " + tokenizer.sep_token + " " + pid_to_bullet[aid]
                    fout.write(f"{aid}\t{_title}\n")
                    fout2.write(f"{aid}\t{_tc}\n")
                    fout3.write(f"{aid}\t{_tcb}\n")
        
with open(os.path.join(out_dir, "anchors_title.test.tsv"), "w") as fout:
    with open(os.path.join(out_dir, "anchors_title_catalog.test.tsv"), "w") as fout2:
        with open(os.path.join(out_dir, "anchors_tcb.test.tsv"), "w") as fout3:
            for example in test_ohop_examples:
                for key in example:
                    if key == "compl_pids":
                        continue
                    aid = key
                    _title = pid_to_title[aid]
                    _tc = _title + " " + tokenizer.sep_token + " " + pid_to_catalog[aid]
                    _tcb = _tc + " " + tokenizer.sep_token + " " + pid_to_bullet[aid]
                    fout.write(f"{aid}\t{_title}\n")
                    fout2.write(f"{aid}\t{_tc}\n")
                    fout3.write(f"{aid}\t{_tcb}\n")
                
with open(os.path.join(out_dir, "arels.compl.train.tsv"), "w") as fout:
    for example in train_ohop_examples:
        for key in example:
            if key == "compl_pids":
                continue
            aid = key 
            compl_pids = example["compl_pids"]
            for compl_pid in compl_pids:
                fout.write(f"{aid}\tQ0\t{compl_pid}\t{1}\n")

with open(os.path.join(out_dir, "arels.compl.val.tsv"), "w") as fout:
    for example in val_ohop_examples:
        for key in example:
            if key == "compl_pids":
                continue
            aid = key 
            compl_pids = example["compl_pids"]
            for compl_pid in compl_pids:
                fout.write(f"{aid}\tQ0\t{compl_pid}\t{1}\n")
                
with open(os.path.join(out_dir, "arels.compl.test.tsv"), "w") as fout:
    for example in test_ohop_examples:
        for key in example:
            if key == "compl_pids":
                continue
            aid = key 
            compl_pids = example["compl_pids"]
            for compl_pid in compl_pids:
                fout.write(f"{aid}\tQ0\t{compl_pid}\t{1}\n")

# %%
# sanity check
for path in os.listdir(out_dir):
    path = os.path.join(out_dir, path)
    ! wc -l $path
    ! head -n 3 $path
    ! tail -n 3 $path
    print("="*100)
# Out:
# 69496 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors_title_catalog.train.tsv
# 501931	SIMPSON 72-in x 80-in Wood Full Lite Right-Hand Inswing Brown Unfinished Double Front Door Solid Core [SEP] Front Doors
# 220006	ReliaBilt Continental 24-in x 80-in Primed 2-Panel Round Top Hollow Core Primed Molded Composite Right Hand Inswing Single Prehung Interior Door [SEP] Prehung Interior Doors
# 1970525	Kraloy Gray PVC Weatherproof New Work/Old Work Standard Enclosure Exterior Electrical Box [SEP] Electrical Boxes
# 1822620	ToughRock 5/8-in 4-ft x 8-ft Fireguard x Regular Drywall Panel [SEP] Drywall Panels
# 132127	Jacuzzi 1500-Watt Inline Heater [SEP] Whirlpool Tub & Air Bath Parts
# 385303	Simply Put 11.1875-in W x 19.375-in H 2-Tier Pull Out Metal Cleaning Caddy [SEP] Cleaning Caddies
# ====================================================================================================
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/product.jsonl
# {"id":1600705,"contents":"ReliaBilt Madison 32-in x 80-in Cream-n-sugar 1-Panel Hollow Core Prefinished Molded Composite Left Hand Inswing Single Prehung Interior Door [SEP] Prehung Interior Doors [SEP] Affordable hollow core construction for areas where sound control is less important Door comes with prefinished paint in Cream-n-Sugar Molded interior passage doors are made with strong, environmentally conscious wood fiber content Perfect for laundry rooms, bathrooms, and bedrooms"}
# {"id":1446112,"contents":"SIMPSON 30-in x 80-in Brown 5-Panel Equal Clear Glass Solid Core Unfinished Knotty Alder Wood Right Hand Inswing Single Prehung Interior Door [SEP] Prehung Interior Doors [SEP] Can be used for a swing door, pocket door, by-pass door, with barn track hardware, with pivot hardware and for any room in the home Engineered all wood stiles and rails with dowel pinned stile and rail joinery Door comes unfinished ready to stain or paint"}
# {"id":1602063,"contents":"SIMPSON 24-in x 80-in Brown Solid Core Unfinished Hardwood Wood Left Hand Inswing Single Prehung Interior Door [SEP] Prehung Interior Doors [SEP] Can be used for a swing door, pocket door, by-pass door, with barn track hardware, with pivot hardware and for any room in the home Engineered all wood stiles and rails with dowel pinned stile and rail joinery Door comes unfinished ready to stain or paint"}
# {"id":341422,"contents":"Goplus Brown 8-Hook Coat Stand [SEP] Coat Racks & Stands [SEP] This hall tree is a perfect combination of hanging rod, coat rack, and shoe rack The simple lines, rustic brown wood tone and elegant matte black finish create a relaxed, reclaimed-style aesthetic Made of high-quality MDF board and powder coated steel frame, our coat rack has good rust and compression resistance to provide you with long-lasting and stable support This three in one hall tree combines multiple storage spaces to maximize space utilization"}
# {"id":319125,"contents":"Benzara Wooden Twist Hall Tree Coat Rack [SEP] Coat Racks & Stands [SEP] Includes one oak finish hall tree coat rack Condition new Six pegs for hats, coats, and scarves Made up of wood"}
# {"id":1676155,"contents":"Trademark Innovations 24-in Expandable 7 Hook Pine Wood Wall Mount Coat Rack- Multipurpose Organizer by Trademark Innovations [SEP] Coat Racks & Stands [SEP] The hook rack extends to 24 in. and has 7 pegs. Hanging Hardware not included Multi purpose can be used for coffee cups, hats, and scarves as well as coats Made of pine wood for added durability By Trademark Innovations Perfect for a hallway, entryway, mudroom or laundry room"}
# ====================================================================================================
# wc: /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/.ipynb_checkpoints: Is a directory
# 0 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/.ipynb_checkpoints
# head: error reading '/home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/.ipynb_checkpoints': Is a directory
# tail: error reading '/home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/.ipynb_checkpoints': Is a directory
# ====================================================================================================
# 69496 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors_title.train.tsv
# 501931	SIMPSON 72-in x 80-in Wood Full Lite Right-Hand Inswing Brown Unfinished Double Front Door Solid Core
# 220006	ReliaBilt Continental 24-in x 80-in Primed 2-Panel Round Top Hollow Core Primed Molded Composite Right Hand Inswing Single Prehung Interior Door
# 1970525	Kraloy Gray PVC Weatherproof New Work/Old Work Standard Enclosure Exterior Electrical Box
# 1822620	ToughRock 5/8-in 4-ft x 8-ft Fireguard x Regular Drywall Panel
# 132127	Jacuzzi 1500-Watt Inline Heater
# 385303	Simply Put 11.1875-in W x 19.375-in H 2-Tier Pull Out Metal Cleaning Caddy
# ====================================================================================================
# 32943 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/arels.compl.val.tsv
# 1904613	Q0	2004113	1
# 692843	Q0	700953	1
# 478212	Q0	836487	1
# 925450	Q0	1616938	1
# 925450	Q0	511344	1
# 925450	Q0	874642	1
# ====================================================================================================
# 8687 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors_title.val.tsv
# 1904613	ReliaBilt Santa Fe 48-in x 80-in Primed 2-Panel Round Top Plank Hollow Core Primed Molded Composite Reversible/Universal Inswing/Outswing Double Prehung Interior Door
# 692843	Roundup Super 1-Gallon Concentrated Weed and Grass Killer
# 478212	Arrow 10-ft x 14-ft Lexington Galvanized Steel Storage Shed
# 751553	Royal Mouldings Limited 1/4-in x 3/4-in x 8-ft Unfinished PVC Bead
# 1498605	Marshalltown 4-in Stainless Steel Drywall Trowel
# 925450	Disney 6.5-ft Lighted The Nightmare Before Christmas Jack Skellington Inflatable
# ====================================================================================================
# 264134 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/arels.compl.train.tsv
# 501931	Q0	2186809	1
# 220006	Q0	1960065	1
# 220006	Q0	774261	1
# 132127	Q0	1043030	1
# 132127	Q0	533708	1
# 385303	Q0	1870322	1
# ====================================================================================================
# 32915 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/arels.compl.test.tsv
# 1711138	Q0	542344	1
# 1711138	Q0	1703024	1
# 1711138	Q0	49604	1
# 1513179	Q0	1062238	1
# 1513179	Q0	1841790	1
# 1513179	Q0	46312	1
# ====================================================================================================
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/collection_bullet.tsv
# 1600705	Affordable hollow core construction for areas where sound control is less important Door comes with prefinished paint in Cream-n-Sugar Molded interior passage doors are made with strong, environmentally conscious wood fiber content Perfect for laundry rooms, bathrooms, and bedrooms
# 1446112	Can be used for a swing door, pocket door, by-pass door, with barn track hardware, with pivot hardware and for any room in the home Engineered all wood stiles and rails with dowel pinned stile and rail joinery Door comes unfinished ready to stain or paint
# 1602063	Can be used for a swing door, pocket door, by-pass door, with barn track hardware, with pivot hardware and for any room in the home Engineered all wood stiles and rails with dowel pinned stile and rail joinery Door comes unfinished ready to stain or paint
# 341422	This hall tree is a perfect combination of hanging rod, coat rack, and shoe rack The simple lines, rustic brown wood tone and elegant matte black finish create a relaxed, reclaimed-style aesthetic Made of high-quality MDF board and powder coated steel frame, our coat rack has good rust and compression resistance to provide you with long-lasting and stable support This three in one hall tree combines multiple storage spaces to maximize space utilization
# 319125	Includes one oak finish hall tree coat rack Condition new Six pegs for hats, coats, and scarves Made up of wood
# 1676155	The hook rack extends to 24 in. and has 7 pegs. Hanging Hardware not included Multi purpose can be used for coffee cups, hats, and scarves as well as coats Made of pine wood for added durability By Trademark Innovations Perfect for a hallway, entryway, mudroom or laundry room
# ====================================================================================================
# 8687 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors_tcb.test.tsv
# 1711138	CARLON 2-Gang Blue Plastic New Work Standard Switch/Outlet Wall Electrical Box [SEP] Electrical Boxes [SEP] For use in new work applications where the wall is not enclosed Durable PVC construction Includes one 1/2 inch knockout Installs to wood or metal stud with bracket Includes 8 integral clamps that hold wires securely 32 Cubic Inch capacity Steel or wood stud mounting
# 80832	CARLON Molded Junction Box-Gang Gray Weatherproof Plastic New Work/Old Work [SEP] Junction Boxes [SEP] To protect electrical equipment used indoor or outdoor Features foam-in place lid with stainless steel screws for superior protection from dirt and moisture Rugged PVC construction that will not rust or corrode even in direct burial applications 4 x 4 x 2 in. deep Recommend male threaded adapters to secure the conduit to the enclosure
# 414913	Oldcastle 0.5-cu ft Tan/Brown Paver Base [SEP] Paver Sand [SEP] Gives hardscape projects a solid base Stabilizes and fills hardscape project areas Materials specified by the Concrete Paver Institute Covers 6 sq. ft. at 1in. depth
# 2171528	Speakman Napa Brushed Nickel Dual Shower Head 2.5-GPM (9.5-LPM) [SEP] Shower Heads [SEP] Features Napa&#8482; Collection fixed and hand shower heads equipped with Anystream&#174; technology for infinite spray possibilities Easy to use diverter allows effortless interchangeability between fixtures Includes 60 in. metal hose and mounting bracket Same quality grade as hotels Easily installs into standard U.S. plumbing systems Self cleaning Nozzles
# 2111763	Harbor Breeze 12-in Brushed Nickel Steel Indoor Universal Ceiling Fan Downrod [SEP] Ceiling Fan Accessories [SEP] 3/4-in inner diameter Harbor Breeze 12-in brushed nickel downrod
# 1513179	Harbor Breeze 18-in Brushed Nickel Steel Indoor Universal Ceiling Fan Downrod [SEP] Ceiling Fan Accessories [SEP] Harbor Breeze 18-in brushed nickel downrod 3/4-in inner diameter
# ====================================================================================================
# 953773 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/queries.tsv
# 0	black and decker saws all
# 1	60 in barn door hardware
# 2	slate refrigerator counter depth
# 953770	polyshades satin espresso
# 953771	colormaxx black
# 953772	samsung pet 70
# ====================================================================================================
# 69496 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors_tcb.train.tsv
# 501931	SIMPSON 72-in x 80-in Wood Full Lite Right-Hand Inswing Brown Unfinished Double Front Door Solid Core [SEP] Front Doors [SEP] Can be used for a swing door, with barn track hardware, with pivot hardware, in a patio swing door or slider system and many other applications for the home&#8217;s exterior Glass 3/4 inch insulated glazing Comes unfinished ready to paint or stain Engineered all wood stiles and rails with dowel pinned stile and rail joinery
# 220006	ReliaBilt Continental 24-in x 80-in Primed 2-Panel Round Top Hollow Core Primed Molded Composite Right Hand Inswing Single Prehung Interior Door [SEP] Prehung Interior Doors [SEP] Molded interior passage doors are made with strong, environmentally conscious wood fiber content Door comes primed ready to paint or stain Perfect for laundry rooms, bathrooms, and bedrooms Affordable hollow core construction for areas where sound control is less important
# 1970525	Kraloy Gray PVC Weatherproof New Work/Old Work Standard Enclosure Exterior Electrical Box [SEP] Electrical Boxes [SEP] Solid PVC gasket Retained gaskets Captive fasteners NEMA type ratings (1, 2, 3, 4, 4X, 6, 6P, 12 and 13) Shoe box style lids
# 1822620	ToughRock 5/8-in 4-ft x 8-ft Fireguard x Regular Drywall Panel [SEP] Drywall Panels [SEP] Gypsum core is noncombustible per ASTM E136 This type of board is often referred to as "blue board" due to the blue face paper that is associated with plaster base boards Face paper is 100% recycled and is designed for the application of gypsum veneer plasters meeting ASTM C587 5/8 In. has been tested in fire-rated assemblies in accordance with ASTM E119 and CAN/ULC S101
# 132127	Jacuzzi 1500-Watt Inline Heater [SEP] Whirlpool Tub & Air Bath Parts [SEP] Requires a dedicated GFCI separate circuit Fits all Jacuzzi&#174; PRIMO and Espree&#174; whirlpool baths Simple fast-fit installation Maintains water temperature without adding additional hot water 1500W, 120V, 60Hz, 12.5amp
# 385303	Simply Put 11.1875-in W x 19.375-in H 2-Tier Pull Out Metal Cleaning Caddy [SEP] Cleaning Caddies [SEP] Removes easily from cabinet for carrying to your task Made of durable steel construction, finished in frosted nickel Installs easily with only tape measure and drill Pull-out caddy is mounted on full extension slides Minimum cabinet opening required for installation: 11.5 in W x 15 in D x 19.5625 in H 4 Cabinet mounting screws and 8 handle mounting screws, included
# ====================================================================================================
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/collection_catalog.tsv
# 1600705	Prehung Interior Doors
# 1446112	Prehung Interior Doors
# 1602063	Prehung Interior Doors
# 341422	Coat Racks & Stands
# 319125	Coat Racks & Stands
# 1676155	Coat Racks & Stands
# ====================================================================================================
# wc: /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/train: Is a directory
# 0 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/train
# head: error reading '/home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/train': Is a directory
# tail: error reading '/home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/train': Is a directory
# ====================================================================================================
# 86870 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/one_hop_examples.jsonl
# {"501931":{"sim_pids":[],"qids":[314525,870482,2084]},"compl_pids":{"2186809":{"sim_pids":[],"qids":[133485,251497,162887],"compl_pids":[]}}}
# {"1711138":{"sim_pids":[80635,215796,14932,1284392,2182678,1856067],"qids":[90777,215640,944202,839750,209847]},"compl_pids":{"542344":{"sim_pids":[1703024,1126877,448706,1647294,1171143,745420,2232334,1838342,1538228,715701,2228295,1703117,127536,1820061,690480,1839168,1145997,1660639],"qids":[614291,39421,36502,136354,922035,702594,303821,254200,932280,872848,922042,944370,385428,14755,176160,497991,574036,232924,604287,905471,121559,717854,326956,104021,504115,163894,562891,433148,278517,513733,174182,805398,370574,502171,530602,112411,26525,612039,242483,166295,886783,397838,243004,409159,34892,218694,701112,833607,519917,682390,948643,936397,53027,674998,514510,143447,756789,766198,69340,811878,841709,368130,920764,940857,261925,234563,171590,890217,144344,29192,315812,598239,947536,299628,73689,901837,895758,614432,401367,448434,926487,23962,405786,687647,301567,572002,710672,775735,934941,272471,518925,251988,428745,280203,859335,129411,620811,853408,703045,438825,637
house wiring","12 2 romex wire","electrical wire","12-2 w ground","12\/2 rome","rolmex","12\/2 wiring","12 gauge electrical wire","12-2 250ft w\/grn","12\/2 with ground electrical wire","12\/3 romex","12-2 250 romeo","14\/2 romex","250' 12-2 romex","14 gauge romex","240 volt wire","wire 12","12-2 wire 1000ft","12 2 with ground","12-2 wire romex","12 guage romex","12-2 nm-b","12.2 awg wire romex","12-2 with ground wire","12\/2 wire 250 ft","250 ft 12\/2 romex","nm-b","12-2 250'","non metallic wire","roman wire","romex 12 2","romex wire 12\/2 with ground","romax 12-2","250\u2019 12\/2 romex","250ft 12\/2 romex","electric cable 12\/2","electric wire","12\/2 nm-b wire","electrical cables","2\/3 wire","romex 122","250 romex","12\/2 cu nm-b w\/g 250-ft","12.2 wire","southwire 250ft 12\/2","12\/2 romax","romex 12\/2 wire","12 romex","12-2 250","romex 12\/2 250","electrical wire 12\/2 with ground","14\/2 romex wire","romex simpull 12\/2","12-3 romex wire","12\/2 nm-b","20 amp wire","12\/2 250","rolex wire","12\/2 nmb","250' 12 2 wire","southwire","12\/2 nmb romex cable","2\/12 electrical wire","12\/2 wg","12\/2 electrical wire 250ft","250 foot romex 12-2","electrical cable 12\/2","#70111","12\/2 nm","electrical 12-2 wire","12\/2 romex 250ft","12-2 romex 250ft","12 awg romex","12 gauge romex wire","12\/2 w ground","12\/2 indoor wire","12\/2 250 ft","12x2 wire","12\/2 romex 250'","12\/2 wg wire","12-2 wire 100feet","12\/2 electric wire","250ft romex 12\/2","12-2 250ft","electrical wiring romex","romex 12 2 with ground","nmb wire","romex 50ft 12\/2","12\/2 romex 250\u2019","250 12-2 romex","12-2 romex 250 ft","12-2 wire with ground","12-2 250 ft","cable 12\/2","12\/2 nm romex","20 amp electrical wire","indoor electric wiring","copper wire 12\/2","10\/2 electrical wire","nmb 12\/2","220 volt wire","250' 12\/2","12-2wg","12\/2 w\/g","12 2 wire 250","interior wire","electrical wire by the foot","12\/2 250ft wire","residential wire","12-2 cable","12\/2 romex 100 ft","romex electrical wire","220 electrical wires","cerro wire","12\/2 copper wire","12-2 romex 250\u2019","12-2 copper wire","southwire 12\/2","12\/2 outdoor wire","romax 12\/2","12ga wire","12\/2 house wire","12\/3 with ground","12\/2 wire 1000ft","12\\2 romex","romex 12-2 wg","electrical wiring 12\/2","number 12 wire","12\/2 gauge electrical wire","12\/2 w\/ground","electric cable14\/2","home wiri ...
# {"220006":{"sim_pids":[],"qids":["continental interior door","pre hung doors interior"]},"compl_pids":{"1960065":{"sim_pids":[],"qids":[],"compl_pids":[]},"774261":{"sim_pids":[1762817,2260136,1704180,1337453,2137859,945220,2188055,1100571,346155,1905920],"qids":["271824","2 panel bifold","folding closet doors","bifold doors","bifold closet doors","bifold door","bi-fold doors","bi fold doors","bi folding doors 36x80","bifold closet doors 36 inch","bifold doors 36x80","36x80 bifold doors","folding doors for closet"],"compl_pids":[]}}}
# {"2171528":{"sim_pids":[],"qids":[]},"compl_pids":{"105141":{"sim_pids":[],"qids":["shower diverter"],"compl_pids":[]}}}
# {"1513179":{"sim_pids":[2111763,90289,1129603,1146781,419545,86972,1598436,1858688],"qids":["99984","brushed nickel downrod","40336","brushed nickel down rod","downrods for ceiling fans","18 inch downrod"]},"compl_pids":{"419545":{"sim_pids":[90289,669106,2111763],"qids":["ceiling fan downrods","down rod","downrod","harbor breeze downrod","down rods","ceiling fan pole","ceiling fan rod nickel","36\" ceiling fan rod","downrod brushed nickel","36\" downrod","40337","102341","brushed nickel downrod","downrods","36 inch ceiling fan downrod","ceiling fan downrod brushed nickel","ceiling fan down rods","harbor breeze down rod","36 inch downrod","harbor breeze 36 inch downrod"],"compl_pids":[2240493,90289,1484172,1924004,1844183,1459643,1841790]},"1930058":{"sim_pids":[1898535,1916979,2071053,1541495,370887,986568,70503,2040775,601897,1850405,599930,801181,982898,134577,1289010,1134277,289474,1409963],"qids":["lights for ceiling","flush mount ceiling lighting","ceiling lights flush mount","light fixtures","flush mount lighting","light fixture ceiling","ceiling lights","bedroom light fixtures","project source lights","light fixtures for kitchen","lighting flush mount","flush mount light","hallway lights","kitchen light","flush ceiling lights","light fixture","bedroom ceiling lights","flush mount lights","bedroom lights","boob light","40803","flush mount","ceiling lighting","ceiling light flush","flush light fixture","light","2 pack lights","flush mount ceiling lights","brushed nickel flush mount light","hallway light","kitchen light fixture","flushmount light","kitchen lighting","project source flush mount light","flushmount","surface mount lights","ceiling lights 2 pack","ceiling flush mount lighting","light for ceiling","entry hallway lighting","light for kitchen","nickel light fixtures","lights for kitchen","13 in. 2-light brushed nickel flush mount (2-pack)","13-in satin nickel flush mount light","0752251","flush ceiling light fixtures","ceiling dome light","ceiling hall lights","project source ceiling light","2 pack flush mount","bedroom ceiling light fixture","project source flush mount","mount light","flush light","dome light 2 pack","project source light fixtures","hallway lights ceiling mounts","laundry room light fixture","project source flush mount ceiling light","kitchen ceiling light","flushmount lights","ceiling lights brushed nickel","contractor lights 2 pack","2 pack light fixtures","overhead bedroom lights","flush mount ceiling lighting 2 pack","2 pack ceiling lighting","lighting for bathroom ceiling","project source light","ceiling fixtures","project source 0555549","project source ceiling lights","ceiling light fixtures bedroom","boob lights","project source flushmount","ceiling mounted light","hall way lights","project source dome lights","project source led light fixture","satin nickel flush mount light","closet ceiling light fixtures","project source 2-pack 13-in satin nickel flush mount light","ceiling light 2 pack","flushmount ceiling lights","lighting model 40803","project source 2 pack","contractor lights","mount lighting","celing lights","lights for bedroom","project source flush mount ceiling fixture","project source light fixture","flush mount lights for kitchen","led light fixtures contractor pack","kitchen lights","flushmount lighting","ceiling light fixtures","ceiling mounted lights","ceiling flush mount light","13\" flush mount","contractor pack lights","ceiling bathroom light","0555549","2 pack dome lights","overhead light","2 pack light","ceiling light bedroom","project source flushmount ceiling fixture","entry light fixtures","lighting for laundry room","nickel flush mount light","contractor pack flush mount ceiling lights","satin nickel ceiling light","flush mount light 2 pack","project source led light","flush mount bathroom light","flush mount 2 pack","nickel ceiling light","ceiling lights project source","2 pack light fixture","2 pack flush mount lights","flush mount closet light","2 light fixtu ...
# ====================================================================================================
# 8687 /home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors
/home/jupyter/jointly_rec_and_search/datasets/rec_search/rec_compl/anchors_tcb.val.tsv
# 1904613	ReliaBilt Santa Fe 48-in x 80-in Primed 2-Panel Round Top Plank Hollow Core Primed Molded Composite Reversible/Universal Inswing/Outswing Double Prehung Interior Door [SEP] Prehung Interior Doors [SEP] Door comes primed ready to paint or stain Affordable hollow core construction for areas where sound control is less important Molded interior passage doors are made with strong, environmentally conscious wood fiber content Perfect for laundry rooms, bathrooms, and bedrooms
# 692843	Roundup Super 1-Gallon Concentrated Weed and Grass Killer [SEP] Weed Killers [SEP] Roundup&#174; Super Concentrate Weed & Grass Killer is a great value for large areas For use around flowers, shrubs and trees; on patios, walkways, driveways, gravel areas and mulch beds; along fences, edging and foundations; as well as large areas such as lawn replacements or garden plot preparation Best Roundup brand concentrate value for widespread weed problems For use around flowers, shrubs, and trees; on patios, walkways, driveways, gravel areas, and mulch beds; along fences and foundations; in large areas for lawn replacements or garden plot preparation For use in tank sprayers Rainproof in 30 minutes Rainproof in 30 minutes Weeds usually yellow and wilt as fast as 2-4 days Easily apply with a Roundup&#174; brand tank sprayer For best results add 2-1/2 oz per 1 gallon of water Weeds usually yellow and wilt in 2-4 days
# 478212	Arrow 10-ft x 14-ft Lexington Galvanized Steel Storage Shed [SEP] Metal Storage Sheds [SEP] 87.9-In high gable steel roof design for additional headroom UV resistant steel panels protect against rot, insects, and extreme weather conditions Electro galvanized steel treated with zinc for strong corrosion resistance Pad-lockable 55.5-in wide sliding doors for easy entry and exit DIY assembly with pre-cut and pre-drilled parts Appealing two tone aesthetics in eggshell and taupe to complement home exteriors Limited 12 year warranty Items pictured in and around shed are not included
# 751553	Royal Mouldings Limited 1/4-in x 3/4-in x 8-ft Unfinished PVC Bead [SEP] Window & Door Moulding [SEP] Made from 100% PVC Rot free, moisture and termite proof material Prefinished white and ready to install Cuts and machines with standard woodworking tools Paintable with 100% latex paint Can be painted with 100% acrylic latex paint Each piece measures 1/4-in thick x 3/4-in wide x 8-ft Limited lifetime warranty Ready to install with fasteners and glue Will not split or crack Can be used in interior and exterior applications Cut and machine with standard woodworking tools Limited lifetime warranty
# 1498605	Marshalltown 4-in Stainless Steel Drywall Trowel [SEP] Trowels [SEP] Lightweight tool made from 1 piece of flexible stainless steel with aluminum mounting Blade set at a 103° angle that flexes to form a perfect 90° corner during use Resilient DuraSoft&#174; handle with finger guard Used to embed tape and smooth out the final layer of mud to taped corners
# 925450	Disney 6.5-ft Lighted The Nightmare Before Christmas Jack Skellington Inflatable [SEP] Outdoor Halloween Decorations & Inflatables [SEP] Self-inflates in seconds and deflates for easy storage &#169; Disney Frighten your guests with this spooky Airblown&#174; inflatable Jack Skellington and boogie Lights up with bright, energy-efficient LEDs for nighttime visibility Frighten your guests with this spooky Airblown&#174; inflatable Jack Skellington and boogie boogie
# ====================================================================================================

# %%
# examples for retrieval model
# 1, anchor: {text: (product_name, catalog_name)}
# 2, compl_ivm_1: {text: (product_name)}

# %%
#train_ohop_examples[3]

# %%
catalogs = product_df.catalog_name.values
print(len(catalogs))
catalogs = catalogs[catalogs != None]
print(len(catalogs))
print(len(np.unique(catalogs)))
print(len(catalogs) / len(np.unique(catalogs)) )

# %%
# Q: Is it catalog_name a predictive factor for complementary item. 
from collections import defaultdict
import matplotlib.pyplot as plt

cata_to_complcatalogs = defaultdict(lambda: defaultdict(int))
prod_to_catalog = {}

products = product_df.product_id.values
catalogs = product_df.catalog_name.values
keep_mask = catalogs != None
products = products[keep_mask]
catalogs = catalogs[keep_mask]
print("number of products = {}, catalogs = {}, unique catalogs = {}".format(len(products), len(catalogs), len(np.unique(catalogs))))
prod_to_catalog = dict(zip(products, catalogs))

for anchor, compl_ivms in anchor_to_compl_ivms.items():
    if anchor not in prod_to_catalog:
        continue
    anc_catalog = prod_to_catalog[anchor]
    for compl_ivm in compl_ivms:
        if compl_ivm not in prod_to_catalog:
            continue
        compl_catalog = prod_to_catalog[compl_ivm]
        cata_to_complcatalogs[anc_catalog][compl_catalog] += 1
        
# complementary items length
compl_items_length = [len(val) for val in cata_to_complcatalogs.values()]
bins = np.append(np.arange(1,11), max(compl_items_length))
print(np.histogram(compl_items_length, bins=bins))

# the population percentage of top-k complementary items 
topks = [1,3,5,7,10]
for topk in topks:
    topk_compls_perc = []
    for anc_catalog in cata_to_complcatalogs:
        freqs = np.array(list(cata_to_complcatalogs[anc_catalog].values()))
        if len(freqs) < topk:
            topk_freqs = freqs
        else:
            topk_freqs = freqs[np.argpartition(freqs, -topk)[-topk:]]
        topk_compls_perc.append(np.sum(topk_freqs) / np.sum(freqs))
    bins = np.linspace(0,1,21)
    print("="*50)
    print(f"topk = {topk}", np.histogram(topk_compls_perc, bins=bins)[0])
    
# A: catalog_name is a predictive factor. Since the top-k complementary category accounts for a large poportion for each anchor_catagory

# %%
# What is the proportion of (anchor_ivm --> compl_ivm)  reversible ?
anchor_to_ivm = set()
rever_anchor_to_ivm = set()
for anc_ivm, compl_ivms in anchor_to_compl_ivms.items():
    for compl_ivm in compl_ivms:
        anchor_to_ivm.add((anc_ivm, compl_ivm))
        if compl_ivm in anchor_to_compl_ivms:
            if anc_ivm in anchor_to_compl_ivms[compl_ivm]:
                rever_anchor_to_ivm.add((anc_ivm, compl_ivm))
print("anchor_to_compl ivm pairs = {:,}, rever pairs = {:,}, proportion = {:.3f}".format(len(anchor_to_ivm), len(rever_anchor_to_ivm), 
                                                                                        len(rever_anchor_to_ivm)/len(anchor_to_ivm)))

# %%
import copy
_exp = one_hop_examples[-10]
_exp = copy.deepcopy(_exp)
new_exp = {}
for key_1, vals_1 in _exp.items():
    if key_1 != "compl_pids":
        new_exp[key_1] = {}
        for key_2, vals_2 in _exp[key_1].items():
            if key_2 == "qids":
                vals_2 = [qid_to_query[qid] for qid in vals_2]
            new_exp[key_1][key_2] = vals_2
    else:
        new_exp[key_1] = {}
        for key_2, vals_2 in _exp[key_1].items():
            new_exp[key_1][key_2] = {}
            for key_3, val_3 in vals_2.items():
                if key_3 == "qids":
                    val_3 = [qid_to_query[qid] for qid in val_3]
                new_exp[key_1][key_2][key_3] = val_3
new_exp

# %%
len(anchor_to_compl_ivms)
