# %%
import os

from google.cloud import bigquery
import pandas as pd 
import numpy as np

client = bigquery.Client()
print("Client creating using default project: {}".format(client.project))

query = """
    SELECT * 
    FROM `gcp-ushi-digital-ds-qa.new_hansi_dataset.search_ClicksData_w_similar_ivms_5core`;
    """
query_job = client.query(query)
search_df = query_job.to_dataframe()

query = """
    SELECT * 
    FROM `gcp-ushi-digital-ds-qa.hansi_dataset.all_products_info`;
    """
query_job = client.query(query)
product_df = query_job.to_dataframe()
print("product_df = {:,}".format(len(product_df)))

all_products = set(product_df.product_id)
similar_ivms = set(np.concatenate(list(search_df.similar_ivms.values)))
ivms = set(search_df.ivm.values)

print("number of unique product = {}, ivms = {}, similar_ivms = {}".format(len(all_products), len(ivms), len(similar_ivms)))
assert len(all_products & similar_ivms) == len(similar_ivms) and len(all_products & ivms) == len(ivms)
# Out:
# Client creating using default project: gcp-ushi-digital-ds-qa
# product_df = 2,260,878
# number of unique product = 2260878, ivms = 159380, similar_ivms = 76572

# %%
# split train, val, test set 
np.random.seed(4680)

HEAD_COUNT=850
TORSO_COUNT=10
np.set_printoptions(suppress=True)

query_to_clicknum = search_df.groupby(["query"])["clicked_numbers"].sum()
print("clicknum of 37.5% and 97.5% quantiles = {}".format(np.quantile(query_to_clicknum.values, [.375, .975])))
print("TORSO COUNT = {}, HEAD_COUNT = {}".format(TORSO_COUNT, HEAD_COUNT))

head_mask = query_to_clicknum.values > HEAD_COUNT
torso_mask = np.logical_and(query_to_clicknum.values > TORSO_COUNT, query_to_clicknum <= HEAD_COUNT)
tail_mask = query_to_clicknum <= TORSO_COUNT
all_queries = np.array([query for query, _ in query_to_clicknum.iteritems()])
head_queries = all_queries[head_mask]
torso_queries = all_queries[torso_mask]
tail_queries = all_queries[tail_mask]
print("number of head, torso, tail queries = {}, {}, {}".format(len(head_queries), len(torso_queries), len(tail_queries)))
assert len(head_queries) + len(torso_queries) + len(tail_queries) == len(query_to_clicknum)

cand_head_queries = np.random.choice(head_queries, size=1000, replace=False)
val_head_queries, test_head_queries = cand_head_queries[:500], cand_head_queries[500:]

cand_torso_queries = np.random.choice(torso_queries, size=2000, replace=False)
val_torso_queries, test_torso_queries = cand_torso_queries[:1000], cand_torso_queries[1000:]

cand_tail_queries = np.random.choice(tail_queries, size = 2000, replace=False)
val_tail_queries, test_tail_queries = cand_tail_queries[:1000], cand_tail_queries[1000:]

print( [len(x) for x in [val_head_queries, val_torso_queries, val_tail_queries]] )
val_queries = np.concatenate([val_head_queries, val_torso_queries, val_tail_queries])
test_queries = np.concatenate([test_head_queries, test_torso_queries, test_tail_queries])
assert len(np.unique(val_queries)) == 2500 and len(np.unique(test_queries)) == 2500, (len(np.unique(val_queries)), len(np.unique(test_queries)))
assert len(set(val_queries) & set(test_queries)) == 0

val_mask = np.in1d(search_df["query"], val_queries)
test_mask = np.in1d(search_df["query"], test_queries)
train_mask = np.logical_and(~val_mask, ~test_mask)
assert np.sum(np.logical_and(np.logical_and(val_mask, test_mask), train_mask)) == 0
assert np.sum(val_mask) + np.sum(test_mask) + np.sum(train_mask) == len(search_df)

train_df = search_df[train_mask]
val_df = search_df[val_mask]
test_df = search_df[test_mask]
# Out:
# clicknum of 37.5% and 97.5% quantiles = [ 11. 853.]
# TORSO COUNT = 10, HEAD_COUNT = 850
# number of head, torso, tail queries = 5697, 138743, 82493
# [500, 1000, 1000]

# %%
# map product --> text

from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
print("sep token = {}".format(tokenizer.sep_token))
from tqdm import tqdm 

product_to_title = {}
product_to_text = {}
no_bulletin_product = set()
no_title_product = set()

def preprocess_text(in_text):
    in_text = in_text.replace("\t", " ")
    in_text = in_text.replace("\n", " ")
    return in_text

for idx, row in tqdm(product_df.iterrows(), total=len(product_df)):
    product_id = row.product_id
    title = row.product_name if row.product_name != None else "No title"
    bullets = row.bullets if row.bullets != None else "No bullets"
    
    if row.product_name == None:
        no_title_product.add(product_id)
    if row.bullets == None:
        no_bulletin_product.add(product_id)
    
    title = preprocess_text(title)
    bullets = preprocess_text(bullets)
    prd_text = title + " " + tokenizer.sep_token + " " + bullets
    assert "\t" not in prd_text and "\n" not in prd_text, prd_text
    
    product_to_title[product_id] = title
    product_to_text[product_id] = prd_text

# sanity check
print("product_to_title and _to_text = {:,}, {:,}, no bulletin product = {:,}, no title product = {:,}".format(
    len(product_to_title), len(product_to_text), len(no_bulletin_product), len(no_title_product)
))

assert len(product_to_title) == len(product_to_text) and len(product_to_text) == len(product_df), (len(product_to_text), len(product_df))
# Out:
# sep token = [SEP]
# 100%|██████████| 2260878/2260878 [03:09<00:00, 11914.95it/s]
# product_to_title and _to_text = 2,260,878, 2,260,878, no bulletin product = 0, no title product = 21

# %%
# map: product --> pid, query --> qid
all_uni_queries = np.unique(search_df["query"])
#sanity check
print("search_df = {}".format(search_df.head()))
print("size = {:,}, query_to_clicked_product = {:.3f}".format(len(search_df), len(search_df)/len(all_uni_queries)))
assert len(search_df) == len(train_df) + len(val_df) + len(test_df)
assert len(all_products) == 2260878, len(all_products)
print("all unique queries = {:,}".format(len(all_uni_queries)))
assert len(all_uni_queries) < len(search_df) - 1000

query_to_qid = {query: qid for qid, query in enumerate(all_uni_queries)}
product_to_pid = {product_id: pid for pid, product_id in enumerate(all_products)} 
pid_to_title = {product_to_pid[product_id]: title for product_id, title in product_to_title.items()}
pid_to_text = {product_to_pid[product_id]: text for product_id, text in product_to_text.items()}

assert len(pid_to_text) == len(pid_to_text) == len(product_to_text) == len(product_to_title)

qid_to_query = {qid: query for query, qid in query_to_qid.items()}
assert len(qid_to_query) == len(query_to_qid)
# Out:
# search_df =                     query                      ivm  clicked_numbers  \
# 0  outdoor rockers chairs  1966700-105558-CR4322BL               12
# 1       cream subway tile      736406-372-C104361P               10
# 2    grass dwarf fountain       90476-13817-022201               11
# 3    downspout extensions           4316-205-33075               98
# 4              gearwrench        4968773-273-9702D               13
#
#   similar_ivms
# 0           []
# 1           []
# 2           []
# 3           []
# 4           []
# size = 915,725, query_to_clicked_product = 4.035
# all unique queries = 226,933

# %%
# write 
import os 
import ujson

out_dir = "/home/jupyter/jointly_rec_and_search/datasets/rec_search/search/"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

# for train
train_qids = set()
# train: queries.train.tsv, qrels.train.tsv
with open(os.path.join(out_dir, "queries.train.tsv"), "w") as fout:
    with open(os.path.join(out_dir, "qrels.train.tsv"), "w") as fout2:
        for idx, row in tqdm(train_df.iterrows(), total=len(train_df)):
            query, product_id = row["query"], row["ivm"]
            assert row["clicked_numbers"] >= 5
            assert "\n" not in query, query
            
            qid = query_to_qid[query]
            pid = product_to_pid[product_id]
            
            if qid not in train_qids:
                fout.write(f"{qid}\t{query}\n")
                train_qids.add(qid)
            fout2.write(f"{qid}\tQ0\t{pid}\t{1}\n")
            
            

# for val
with open(os.path.join(out_dir, "queries.val.tsv"), "w") as fout:
    for query in val_queries:
        fout.write(f"{query_to_qid[query]}\t{query}\n")
with open(os.path.join(out_dir, "qrels.val.tsv"), "w") as fout:
    for idx, row in tqdm(val_df.iterrows(), total=len(val_df)):
        query, product_id = row["query"], row["ivm"]
        assert row["clicked_numbers"] >= 5
        assert "\n" not in query, query
        
        qid = query_to_qid[query]
        pid = product_to_pid[product_id]
        
        assert qid not in train_qids
        fout.write(f"{qid}\tQ0\t{pid}\t{1}\n")
        

# for test
with open(os.path.join(out_dir, "queries.test.tsv"), "w") as fout:
    for query in test_queries:
        fout.write(f"{query_to_qid[query]}\t{query}\n")
with open(os.path.join(out_dir, "queries.test.head.tsv"), "w") as fout:
    for query in test_head_queries:
        fout.write(f"{query_to_qid[query]}\t{query}\n")
with open(os.path.join(out_dir, "queries.test.torso.tsv"), "w") as fout:
    for query in test_torso_queries:
        fout.write(f"{query_to_qid[query]}\t{query}\n")
with open(os.path.join(out_dir, "queries.test.tail.tsv"), "w") as fout:
    for query in test_tail_queries:
        fout.write(f"{query_to_qid[query]}\t{query}\n")
with open(os.path.join(out_dir, "qrels.test.tsv"), "w") as fout:
    for idx, row in tqdm(test_df.iterrows(), total=len(test_df)):
        query, product_id = row["query"], row["ivm"]
        assert row["clicked_numbers"] >= 5
        assert "\n" not in query, query
        
        qid = query_to_qid[query]
        pid = product_to_pid[product_id]
        
        assert qid not in train_qids
        fout.write(f"{qid}\tQ0\t{pid}\t{1}\n")
        
with open(os.path.join(out_dir, "qrels.test.head.tsv"), "w") as fout1:
    with open(os.path.join(out_dir, "qrels.test.torso.tsv"), "w") as fout2:
        with open(os.path.join(out_dir, "qrels.test.tail.tsv"), "w") as fout3:
            for idx, row in tqdm(test_df.iterrows(), total=len(test_df)):
                query, product_id = row["query"], row["ivm"]
                assert row["clicked_numbers"] >= 5
                assert "\n" not in query, query

                qid = query_to_qid[query]
                pid = product_to_pid[product_id]

                assert qid not in train_qids
                if query in test_head_queries:
                    fout1.write(f"{qid}\tQ0\t{pid}\t{1}\n")
                elif query in test_torso_queries:
                    fout2.write(f"{qid}\tQ0\t{pid}\t{1}\n")
                elif query in test_tail_queries:
                    fout3.write(f"{qid}\tQ0\t{pid}\t{1}\n")
                else:
                    raise ValueError(f"{query} not in test_queries")
            
# collection
with open(os.path.join(out_dir, "collection_title.tsv"), "w") as fout:
    for pid, title in pid_to_title.items():
        assert "\n" not in title, title
        fout.write(f"{pid}\t{title}\n")

with open(os.path.join(out_dir, "collection.tsv"), "w") as fout:
    for pid, text in pid_to_text.items():
        assert "\n" not in text, text 
        fout.write(f"{pid}\t{text}\n")
        
with open(os.path.join(out_dir, "product.jsonl"), "w") as fout:
    for pid, text in pid_to_text.items():
        example = {"id": pid, "contents": text}
        fout.write(ujson.dumps(example) + "\n")
        
# product_to_pid
with open(os.path.join(out_dir, "pid_productid_map.tsv"), "w") as fout:
    for product_id, pid in product_to_pid.items():
        fout.write(f"{pid}\t{product_id}\n")

# anchors.train.tsv, arels.train.tsv
aid_to_pids = {}
for idx, row in train_df.iterrows():
    ivm, similar_ivms = row["ivm"], row["similar_ivms"]
    
    if len(similar_ivms) == 0:
        continue
    aid = product_to_pid[ivm]
    pids = [product_to_pid[_ivm] for _ivm in similar_ivms]
    
    if aid not in aid_to_pids:
        aid_to_pids[aid] = set()
    
    for pid in pids:
        aid_to_pids[aid].add(pid)

with open(os.path.join(out_dir, "anchors.train.tsv"), "w") as fout:
    with open(os.path.join(out_dir, "arels.train.tsv"), "w") as fout2:
        for aid in aid_to_pids:
            fout.write(f"{aid}\t{pid_to_title[aid]}\n")
            for pid in list(aid_to_pids[aid]):
                fout2.write(f"{aid}\tQ0\t{pid}\t{1}\n")
# Out:
# 100%|██████████| 870971/870971 [00:41<00:00, 21192.85it/s]
# 100%|██████████| 23265/23265 [00:01<00:00, 20903.28it/s]
# 100%|██████████| 21489/21489 [00:01<00:00, 21017.52it/s]

# %%
# sanity check
for path in os.listdir(out_dir):
    path = os.path.join(out_dir, path)
    ! wc -l $path
    ! head -n 3 $path
    ! tail -n 3 $path
    print("="*100)
# Out:
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/pid_productid_map.tsv
# 0	4899553-101078-34314340
# 1	1940852-105820-2540298-24-24X24
# 2	1595385-483-RDCDS.TWSO.A21O
# 2260875	1925761-105820-2481501-24-36X36
# 2260876	1421734-101635-VMW15610SW
# 2260877	298702-16878-55563
# ====================================================================================================
# 83440 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/anchors.train.tsv
# 1277611	Eagle Clear High-gloss Acrylic Waterproofer (1-Gallon)
# 2221897	Eagle Clear High-gloss Transparent Acrylic Waterproofer (1-Gallon)
# 1700120	Eagle Clear High-gloss Transparent Acrylic Waterproofer (5-Gallon)
# 90380	 7.25-in x 12-ft Unfinished Pine Shiplap Wall Plank (Coverage Area: 7.25-sq ft)
# 1084011	 7.125-in 12-ft Pine Tongue and Groove Wall Plank (Coverage Area: 7.125-sq ft)
# 1347915	Top Choice 5.5-in x 8-ft Unfinished Pine Tongue and Groove Wall Plank (Coverage Area: 3.6667-sq ft)
# ====================================================================================================
# 387699 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/arels.train.tsv
# 1277611	Q0	1051217	1
# 2221897	Q0	1051217	1
# 1700120	Q0	1051217	1
# 1347915	Q0	214089	1
# 1347915	Q0	2051800	1
# 1347915	Q0	1871037	1
# ====================================================================================================
# 2500 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/queries.test.tsv
# 189079	small refrigerator without freezer
# 210369	vegetable seeds
# 97919	fluorescent light bulbs
# 19985	3/4 in pvc coupling socket
# 181870	sealer foam
# 60630	cali natural elm
# ====================================================================================================
# 2500 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/queries.val.tsv
# 136557	mail box residential
# 72307	corrugated drain pipe
# 140511	metal studs
# 101906	galvanized water buckets
# 17971	2x4x8 weather treated
# 63334	ceiling light globe replacement
# ====================================================================================================
# 1000 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/queries.test.torso.tsv
# 203941	touchscreen refrigerator
# 175653	round box
# 175998	roundup concentrate weed killer
# 65947	chinese wisteria
# 69716	concrete circular saw blade
# 163278	portable scaffolding
# ====================================================================================================
# 221933 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/queries.train.tsv
# 150882	outdoor rockers chairs
# 75048	cream subway tile
# 108656	grass dwarf fountain
# 58270	brown shiplap
# 161528	polar white shiplap
# 9946	183094
# ====================================================================================================
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/product.jsonl
# {"id":1778658,"contents":"Heartland 12-ft x 16-ft Statesman Gable Engineered Storage Shed (Floor Included) [SEP] Extra-wide 64-in. double doors and 7-ft. tall side wall height 7-Ft tall side wall height fits rakes, shovels, ladders and more Bonus features include complete floor system, storage loft, two shelves, vents and gable window Pre-cut kit, nothing to saw &#65279;7-ft tall side wall height fits rakes, shovels, ladders and more Extra-wide 64-in pre-hung doors with heavy-duty continuous hinges to prevent sagging Heavy-duty wood construction stands up to demanding wind and snow loads Bonus features include complete floor system, storage loft, two shelves and a gable window Pre-hung doors with heavy-duty continuous hinges to prevent sagging Treated, engineered wood siding is factory-primed and ready to paint Full on-site installation available; see Lowe's associate 12-Year limited material warranty 10-Year limited material warranty Will not warp like plastic sheds, will not rust like metal sheds"}
# {"id":467018,"contents":"CRAFTSMAN 8-in Steel Adjustable Wrench [SEP] VERSATILITY: Wide Opening Jaws for Added Versatility Meets or exceeds ASME specifications Automotive Mechanical Applications Home Repair Applications CORROSION RESISTANCE: Chrome Finish for Corrosion Resistance CONVENIENCE: Metric and SAE Scale for easy gauging of work piece size Includes: (1) 8-in All Steel Adjustable Wrench Full Lifetime Warranty"}
# {"id":1605494,"contents":"K Tool International 17.7-in Steel Adjustable Wrench [SEP] Manufactured with drop-forged, heat-treated alloy steel for maximum strength and light weight Chrome plated Jaw capacity: 2-1\/4 In., one 15 In. adjustable wrench Drop forged and heat treated"}
# {"id":2253321,"contents":"Hanover 1-ft 2-ft Saltbox Engineered Storage Shed (Floor Included) [SEP] Outdoor Wooden Storage Shed with Pitched Roof and 2 Corner Shelves Sturdy, fir wood construction Includes 2 corner shelves to keep your shed organized Pitched, asphalt roof is waterproof 7 cubic feet internal storage capacity Painted Grey finish Door opening is 22.8 in W x 47.8 in H 1 year limited warranty Floor included"}
# {"id":1286860,"contents":"Little Cottage Company 10-ft x 16-ft Classic Gambrel Engineered Storage Shed [SEP] Customer provides shingles, roof drip-edge, paint, and flooring materials Made with Amish craftsmanship Everything is precut, labeled, and ready to assemble, no extra cutting - only general knowledge of the required tools is needed Premium LP smart side paneling grooved 4 in. O.C. treated to resist fungal decay and insect infestation, primed and ready for paint - 50 year rot resistant warranty Screws, latches, handles and nails are included along with color photo instruction manual and wall layout blueprint Quality rot resistant gable, eaves, and corner trim 2-Person home delivery - when the pallet reaches the customer's local terminal, the shipping company will contact the customer to set up delivery, the customer is responsible for providing at least 2 people at delivery to help unload the kit Check with your local building department for specific requirements for building your project because additional materials may be required to meet local codes including H-clips, tie-downs, rafter ties, hurricane strapping, etc"}
# {"id":1849343,"contents":"Little Cottage Company 10-ft x 20-ft Classic Gambrel Engineered Storage Shed [SEP] Made with Amish craftsmanship Everything is precut, labeled, and ready to assemble, no extra cutting - only general knowledge of the required tools is needed Premium LP smart side paneling grooved 4 in. O.C. treated to resist fungal decay and insect infestation, primed and ready for paint - 50 year rot resistant warranty Customer provides shingles, roof drip-edge, paint, and flooring materials Check with your local building department for specific requirements for building your project because additional materials may be required to meet local codes including H-clips, tie-downs, rafter ties, hurricane strapping, etc Screws, latches, handles and nails are included along with color photo instruction manual and wall layout blueprint Quality rot resistant gable, eaves, and corner trim 2-Person home delivery - when the pallet reaches the customer's local terminal, the shipping company will contact the customer to set up delivery, the customer is responsible for providing at least 2 people at delivery to help unload the kit"}
# ====================================================================================================
# 21489 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/qrels.test.tsv
# 47762	Q0	1601980	1
# 44785	Q0	1219576	1
# 205958	Q0	1682049	1
# 83475	Q0	114730	1
# 93125	Q0	38213	1
# 181208	Q0	1265796	1
# ====================================================================================================
# 500 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/queries.test.head.tsv
# 189079	small refrigerator without freezer
# 210369	vegetable seeds
# 97919	fluorescent light bulbs
# 17816	2x4x16 pine lumber
# 102128	garage door opener
# 55957	bosch 500 series dishwasher
# ====================================================================================================
# 23265 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/qrels.val.tsv
# 61699	Q0	780217	1
# 199225	Q0	2180992	1
# 60339	Q0	677689	1
# 203188	Q0	246466	1
# 203188	Q0	1084011	1
# 203188	Q0	1347915	1
# ====================================================================================================
# 1000 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/queries.test.tail.tsv
# 197343	style selections fire pit
# 139840	metal gable trim
# 32413	6" drain pipe
# 19985	3/4 in pvc coupling socket
# 181870	sealer foam
# 60630	cali natural elm
# ====================================================================================================
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/collection.tsv
# 1778658	Heartland 12-ft x 16-ft Statesman Gable Engineered Storage Shed (Floor Included) [SEP] Extra-wide 64-in. double doors and 7-ft. tall side wall height 7-Ft tall side wall height fits rakes, shovels, ladders and more Bonus features include complete floor system, storage loft, two shelves, vents and gable window Pre-cut kit, nothing to saw &#65279;7-ft tall side wall height fits rakes, shovels, ladders and more Extra-wide 64-in pre-hung doors with heavy-duty continuous hinges to prevent sagging Heavy-duty wood construction stands up to demanding wind and snow loads Bonus features include complete floor system, storage loft, two shelves and a gable window Pre-hung doors with heavy-duty continuous hinges to prevent sagging Treated, engineered wood siding is factory-primed and ready to paint Full on-site installation available; see Lowe's associate 12-Year limited material warranty 10-Year limited material warranty Will not warp like plastic sheds, will not rust like metal sheds
# 467018	CRAFTSMAN 8-in Steel Adjustable Wrench [SEP] VERSATILITY: Wide Opening Jaws for Added Versatility Meets or exceeds ASME specifications Automotive Mechanical Applications Home Repair Applications CORROSION RESISTANCE: Chrome Finish for Corrosion Resistance CONVENIENCE: Metric and SAE Scale for easy gauging of work piece size Includes: (1) 8-in All Steel Adjustable Wrench Full Lifetime Warranty
# 1605494	K Tool International 17.7-in Steel Adjustable Wrench [SEP] Manufactured with drop-forged, heat-treated alloy steel for maximum strength and light weight Chrome plated Jaw capacity: 2-1/4 In., one 15 In. adjustable wrench Drop forged and heat treated
# 2253321	Hanover 1-ft 2-ft Saltbox Engineered Storage Shed (Floor Included) [SEP] Outdoor Wooden Storage Shed with Pitched Roof and 2 Corner Shelves Sturdy, fir wood construction Includes 2 corner shelves to keep your shed organized Pitched, asphalt roof is waterproof 7 cubic feet internal storage capacity Painted Grey finish Door opening is 22.8 in W x 47.8 in H 1 year limited warranty Floor included
# 1286860	Little Cottage Company 10-ft x 16-ft Classic Gambrel Engineered Storage Shed [SEP] Customer provides shingles, roof drip-edge, paint, and flooring materials Made with Amish craftsmanship Everything is precut, labeled, and ready to assemble, no extra cutting - only general knowledge of the required tools is needed Premium LP smart side paneling grooved 4 in. O.C. treated to resist fungal decay and insect infestation, primed and ready for paint - 50 year rot resistant warranty Screws, latches, handles and nails are included along with color photo instruction manual and wall layout blueprint Quality rot resistant gable, eaves, and corner trim 2-Person home delivery - when the pallet reaches the customer's local terminal, the shipping company will contact the customer to set up delivery, the customer is responsible for providing at least 2 people at delivery to help unload the kit Check with your local building department for specific requirements for building your project because additional materials may be required to meet local codes including H-clips, tie-downs, rafter ties, hurricane strapping, etc
# 1849343	Little Cottage Company 10-ft x 20-ft Classic Gambrel Engineered Storage Shed [SEP] Made with Amish craftsmanship Everything is precut, labeled, and ready to assemble, no extra cutting - only general knowledge of the required tools is needed Premium LP smart side paneling grooved 4 in. O.C. treated to resist fungal decay and insect infestation, primed and ready for paint - 50 year rot resistant warranty Customer provides shingles, roof drip-edge, paint, and flooring materials Check with your local building department for specific requirements for building your project because additional materials may be required to meet local codes including H-clips, tie-downs, rafter ties, hurricane strapping, etc Screws, latches, handles and nails are included along with color photo instruction manual and wall layout blueprint Quality rot resistant gable, eaves, and corner trim 2-Person home delivery - when the pallet reaches the customer's local terminal, the shipping company will contact the customer to set up delivery, the customer is responsible for providing at least 2 people at delivery to help unload the kit
# ====================================================================================================
# 870971 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/qrels.train.tsv
# 150882	Q0	8186	1
# 75048	Q0	478746	1
# 108656	Q0	551375	1
# 203191	Q0	1347915	1
# 200526	Q0	1347915	1
# 203178	Q0	1347915	1
# ====================================================================================================
# 2260878 /home/jupyter/jointly_rec_and_search/datasets/rec_search/search/collection_title.tsv
# 1778658	Heartland 12-ft x 16-ft Statesman Gable Engineered Storage Shed (Floor Included)
# 467018	CRAFTSMAN 8-in Steel Adjustable Wrench
# 1605494	K Tool International 17.7-in Steel Adjustable Wrench
# 2253321	Hanover 1-ft 2-ft Saltbox Engineered Storage Shed (Floor Included)
# 1286860	Little Cottage Company 10-ft x 16-ft Classic Gambrel Engineered Storage Shed
# 1849343	Little Cottage Company 10-ft x 20-ft Classic Gambrel Engineered Storage Shed
# ====================================================================================================

# %%
with open(os.path.join(out_dir, "qrels.test.head.tsv"), "w") as fout1:
    with open(os.path.join(out_dir, "qrels.test.torso.tsv"), "w") as fout2:
        with open(os.path.join(out_dir, "qrels.test.tail.tsv"), "w") as fout3:
            for idx, row in tqdm(test_df.iterrows(), total=len(test_df)):
                query, product_id = row["query"], row["ivm"]
                assert row["clicked_numbers"] >= 5
                assert "\n" not in query, query

                qid = query_to_qid[query]
                pid = product_to_pid[product_id]

                assert qid not in train_qids
                if query in test_head_queries:
                    fout1.write(f"{qid}\tQ0\t{pid}\t{1}\n")
                elif query in test_torso_queries:
                    fout2.write(f"{qid}\tQ0\t{pid}\t{1}\n")
                elif query in test_tail_queries:
                    fout3.write(f"{qid}\tQ0\t{pid}\t{1}\n")
                else:
                    raise ValueError(f"{query} not in test_queries")
# Out:
# 100%|██████████| 21489/21489 [00:01<00:00, 14396.67it/s]
